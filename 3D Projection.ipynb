# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

figure = plt.figure(1, figsize = (25, 10))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z,
                                rstride=1,
                                cstride=1,
                                cmap=matplotlib.cm.rainbow_r,
                                linewidth=0.9)
plt.show()

# %%
import numpy as np
np.random.seed(19680801)
plt.figure(figsize=(10,25))
N = 20
theta = np.linspace(0.0, 2*np.pi, N, endpoint=False)
radi = 10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
colors = plt.cm.viridis(radi /10)
ax = plt.subplot(111, projection = 'polar')
ax.bar(theta, radi, width = width, bottom = 0.0, color=colors,alpha=0.9)
plt.show()

# %%
plt.figure(figsize=(20,15))
plt.contourf(X, Y, Z, cmap=matplotlib.cm.rainbow)
plt.colorbar()
plt.show()

# %%
from numpy.random import rand
x, y = rand(2,100)
plt.figure(figsize=(30,15))
plt.scatter(x,y)
plt.show()

# %%
x, y, scale  = rand(3,100)
scale = 500*scale**5
plt.scatter(x,y, s = scale)
plt.show()

# %%
for color in ['red', 'blue', 'green']:
     n = 100
     x, y = rand(2,n)
     scale = 500.0 * rand(n) ** 5
     plt.scatter(x, y, s = scale, c = color, alpha = 0.3, edgecolors='blue')
plt.grid(True)
plt.show()

# %%
from numpy.random import randn

def plot_line(axis, slope, intercept, **kargs):
   xmin, xmax = axis.get_xlim()
   plt.plot([xmin, xmax], [xmin*slope+intercept, xmax*slope+intercept], **kargs)

x = randn(1000)
y = 0.5*x + 5 + randn(1000)*2
plt.figure(figsize= (16,9))
plt.axis([-2.5, 2.5, -5, 15])
plt.scatter(x, y, alpha=0.3)
plt.plot(1, 0, "ro")
plt.vlines(1, -5, 0, color="red")
plt.hlines(0, -2.5, 1, color="red")
plot_line(axis=plt.gca(), slope=0.5, intercept=5, color="magenta")
plt.grid(True)
plt.show()

# %%
data = [1, 1.1, 1.8, 2, 2.1, 3.2, 3, 3, 3, 3]
plt.subplot(211)
plt.hist(data, bins = 10, rwidth=0.5)

plt.subplot(212)
plt.hist(data, bins = [1, 1.5, 2, 2.5, 3], rwidth=0.95)
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.show()

# %%
data1 = np.random.randn(400)
data2 = np.random.randn(500) + 3
data3 = np.random.randn(450) + 6
data4a = np.random.randn(200) + 9
data4b = np.random.randn(100) + 10

plt.hist(data1, bins=5, color='g', alpha=0.75, label='bar hist') # default histtype='bar'
plt.hist(data2, color='b', alpha=0.65, histtype='stepfilled', label='stepfilled hist')
plt.hist(data3, color='r', histtype='step', label='step hist')
plt.hist((data4a, data4b), color=('y','k'), alpha=0.55, histtype='barstacked', label=('barstacked a', 'barstacked b'))

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.image as mpimg
img = mpimg.imread('my_square_function.png') 
print(img.shape, img.dtype)
# Out:
# (288, 432, 4) float32

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)

# %%
plt.show()

# %%
img = np.arange(100*100).reshape(100,100)
plt.imshow(img)
print(img)
# Out:
# [[   0    1    2 ...   97   98   99]
#  [ 100  101  102 ...  197  198  199]
#  [ 200  201  202 ...  297  298  299]
#  ...
#  [9700 9701 9702 ... 9797 9798 9799]
#  [9800 9801 9802 ... 9897 9898 9899]
#  [9900 9901 9902 ... 9997 9998 9999]]

# %%
img = np.empty((20, 30, 3))
img[: , :10] = [0, 0, 0.6]
plt.imshow(img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img[:, :20] = [0.6, 0, 0]
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(img, interpolation = "nearest")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(30,15))
ax = fig.gca(projection='3d')

X, Y = np.mgrid[0:6*np.pi:0.25, 0:4*np.pi:0.25]
Z = np.sqrt(np.abs(np.cos(X) + np.cos(Y)))

ax.plot_surface(X + 1e5, Y + 1e5, Z, cmap='autumn', cstride=2, rstride=2)

ax.set_xlabel("X label")
ax.set_ylabel("Y label")
ax.set_zlabel("Z label")
ax.set_zlim(0, 2)

plt.show()
